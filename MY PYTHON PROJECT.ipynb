# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Importing IPL dataset**

# %%
data = pd.read_csv("eda_complete_dataset.csv")
data
# Out:
#        order_id           order_date  customer_age  gender  country  \
# 0             1  2022-01-01 00:00:00            62    Male   Canada
# 1             2  2022-01-01 01:00:00            65  Female   Canada
# 2             3  2022-01-01 02:00:00            18  Female    India
# 3             4  2022-01-01 03:00:00            21  Female  Germany
# 4             5  2022-01-01 04:00:00            21    Male   Canada
# ...         ...                  ...           ...     ...      ...
# 11995     11996  2023-05-15 19:00:00            65  Female      USA
# 11996     11997  2023-05-15 20:00:00            24    Male      USA
# 11997     11998  2023-05-15 21:00:00            65    Male  Germany
# 11998     11999  2023-05-15 22:00:00            43  Female       UK
# 11999     12000  2023-05-15 23:00:00            64  Female   Canada
#
#       product_category  quantity  unit_price  discount payment_method  \
# 0                 Food         5       28.50      0.13    Net Banking
# ...

# %%
data.shape
# Out:
# (12000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of        order_id           order_date  customer_age  gender  country  \
# 0             1  2022-01-01 00:00:00            62    Male   Canada
# 1             2  2022-01-01 01:00:00            65  Female   Canada
# 2             3  2022-01-01 02:00:00            18  Female    India
# 3             4  2022-01-01 03:00:00            21  Female  Germany
# 4             5  2022-01-01 04:00:00            21    Male   Canada
# ...         ...                  ...           ...     ...      ...
# 11995     11996  2023-05-15 19:00:00            65  Female      USA
# 11996     11997  2023-05-15 20:00:00            24    Male      USA
# 11997     11998  2023-05-15 21:00:00            65    Male  Germany
# 11998     11999  2023-05-15 22:00:00            43  Female       UK
# 11999     12000  2023-05-15 23:00:00            64  Female   Canada
#
#       product_category  quantity  unit_price  discount payment_method  \
# ...

# %%
data.isnull()
# Out:
#        order_id  order_date  customer_age  gender  country  product_category  \
# 0         False       False         False   False    False             False
# 1         False       False         False   False    False             False
# 2         False       False         False   False    False             False
# 3         False       False         False   False    False             False
# 4         False       False         False   False    False             False
# ...         ...         ...           ...     ...      ...               ...
# 11995     False       False         False   False    False             False
# 11996     False       False         False   False    False             False
# 11997     False       False         False   False    False             False
# 11998     False       False         False   False    False             False
# 11999     False       False         False   False    False             False
#
# ...

# %%
data.isna().any()
# Out:
# order_id            False
# order_date          False
# customer_age        False
# gender              False
# country             False
# product_category    False
# quantity            False
# unit_price          False
# discount            False
# payment_method      False
# total_price         False
# is_returned         False
# dtype: bool

# %%
data.isna().any().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#           order_id  customer_age      quantity    unit_price      discount  \
# count  12000.00000  12000.000000  12000.000000  12000.000000  12000.000000
# mean    6000.50000     43.682333      5.028083    251.651357      0.249820
# std     3464.24595     15.021714      2.585701    143.036958      0.143928
# min        1.00000     18.000000      1.000000      5.070000      0.000000
# 25%     3000.75000     30.000000      3.000000    125.795000      0.130000
# 50%     6000.50000     44.000000      5.000000    251.475000      0.250000
# 75%     9000.25000     57.000000      7.000000    375.607500      0.380000
# max    12000.00000     69.000000      9.000000    499.870000      0.500000
#
#         total_price   is_returned
# count  12000.000000  12000.000000
# mean     952.427864      0.102583
# std      824.366478      0.303427
# min        3.920000      0.000000
# 25%      297.797500      0.000000
# 50%      701.680000      0.000000
# 75%     1413.757500      0.000000
# ...

# %%
data.columns
# Out:
# Index(['order_id', 'order_date', 'customer_age', 'gender', 'country',
#        'product_category', 'quantity', 'unit_price', 'discount',
#        'payment_method', 'total_price', 'is_returned'],
#       dtype='object')

# %% [markdown]
# **1.HOW MANY COUNTRY IS INVOLVED IN THIS DATASET ?**

# %%
data["country"].unique()
# Out:
# array(['Canada', 'India', 'Germany', 'USA', 'UK'], dtype=object)

# %%
data["country"].nunique()
# Out:
# 5

# %% [markdown]
# **2.WHAT IS THE MAX DISCOUNT PERCENTAGE ?**

# %%
data["discount"].max()
# Out:
# 0.5

# %%
data[data["discount"]== 0.5]
# Out:
#        order_id           order_date  customer_age  gender  country  \
# 3             4  2022-01-01 03:00:00            21  Female  Germany
# 11           12  2022-01-01 11:00:00            41    Male       UK
# 206         207  2022-01-09 14:00:00            39    Male  Germany
# 283         284  2022-01-12 19:00:00            23  Female       UK
# 388         389  2022-01-17 04:00:00            31    Male       UK
# ...         ...                  ...           ...     ...      ...
# 11489     11490  2023-04-24 17:00:00            35    Male       UK
# 11585     11586  2023-04-28 17:00:00            33    Male    India
# 11709     11710  2023-05-03 21:00:00            57    Male       UK
# 11835     11836  2023-05-09 03:00:00            41  Female   Canada
# 11926     11927  2023-05-12 22:00:00            31    Male    India
#
#       product_category  quantity  unit_price  discount payment_method  \
# 3             Clothing         3      203.96       0.5           Cash
# ...

# %% [markdown]
# **3.WHICH IS THE HIGHEST NUMBER OF PAYMENT METHOD**

# %%
data["payment_method"].unique()
# Out:
# array(['Net Banking', 'Credit Card', 'Cash', 'Debit Card', 'UPI'],
#       dtype=object)

# %%
data1 = data["payment_method"].value_counts()
sns.barplot(x = data1 , y = data1.index)
plt.show()

# %%
data1
# Out:
# payment_method
# Cash           2521
# Credit Card    2419
# Debit Card     2394
# Net Banking    2370
# UPI            2296
# Name: count, dtype: int64

# %% [markdown]
# **4.Are there any missing values in critical columns ?**

# %%
data.isnull().sum()
# Out:
# order_id            0
# order_date          0
# customer_age        0
# gender              0
# country             0
# product_category    0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# total_price         0
# is_returned         0
# dtype: int64

# %% [markdown]
# **5.Are there invalid values (negative quantity, discount > 1, age < 0)?**

# %%
data.describe()
# Out:
#           order_id  customer_age      quantity    unit_price      discount  \
# count  12000.00000  12000.000000  12000.000000  12000.000000  12000.000000
# mean    6000.50000     43.682333      5.028083    251.651357      0.249820
# std     3464.24595     15.021714      2.585701    143.036958      0.143928
# min        1.00000     18.000000      1.000000      5.070000      0.000000
# 25%     3000.75000     30.000000      3.000000    125.795000      0.130000
# 50%     6000.50000     44.000000      5.000000    251.475000      0.250000
# 75%     9000.25000     57.000000      7.000000    375.607500      0.380000
# max    12000.00000     69.000000      9.000000    499.870000      0.500000
#
#         total_price   is_returned
# count  12000.000000  12000.000000
# mean     952.427864      0.102583
# std      824.366478      0.303427
# min        3.920000      0.000000
# 25%      297.797500      0.000000
# 50%      701.680000      0.000000
# 75%     1413.757500      0.000000
# ...

# %% [markdown]
# **6.What is the age distribution of customers?**

# %%
plt.hist(data['customer_age'],bins=10,edgecolor='white',linewidth=2)
plt.xlabel('Customer Age')
plt.ylabel('Number of Customers')
plt.title('Age Distribution of Customers')
plt.show()

# %% [markdown]
# **7.Which product categories sell the most units?**

# %%
data.groupby('product_category')['quantity'].sum().sort_values(ascending = False)
# Out:
# product_category
# Books          12529
# Food           12059
# Furniture      12035
# Clothing       11963
# Electronics    11751
# Name: quantity, dtype: int64

# %% [markdown]
# **8. What is the distribution of unit_price and total_price?**

# %%
data[['unit_price','total_price']].describe()
# Out:
#          unit_price   total_price
# count  12000.000000  12000.000000
# mean     251.651357    952.427864
# std      143.036958    824.366478
# min        5.070000      3.920000
# 25%      125.795000    297.797500
# 50%      251.475000    701.680000
# 75%      375.607500   1413.757500
# max      499.870000   4382.560000

# %% [markdown]
# **9.Does customer_age correlate with spending?**

# %%
data[['customer_age','total_price']].corr()
# Out:
#               customer_age  total_price
# customer_age      1.000000    -0.016723
# total_price      -0.016723     1.000000

# %%
data.groupby('customer_age')['total_price'].sum().reset_index()
# Out:
#     customer_age  total_price
# 0             18    241207.43
# 1             19    230378.03
# 2             20    187969.64
# 3             21    219947.35
# 4             22    220255.01
# 5             23    254962.04
# 6             24    215346.02
# 7             25    211681.02
# 8             26    215830.61
# 9             27    224191.16
# 10            28    211483.34
# 11            29    257049.10
# 12            30    226272.06
# 13            31    192630.57
# 14            32    188406.91
# 15            33    235953.86
# 16            34    214355.83
# 17            35    244793.07
# 18            36    212253.70
# 19            37    208270.46
# 20            38    210070.53
# 21            39    199634.93
# 22            40    209020.48
# 23            41    205975.63
# 24            42    213184.69
# 25            43    239437.23
# 26            44    203704.50
# 27            45    227124.21
# 28            46    223329.26
# 29            47    256041.33
# ...

# %% [markdown]
# **10.Is order_date properly parsed as datetime?**

# %%
data['order_date'].dtype
# Out:
# dtype('O')

# %%
data['order_date'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11995    False
# 11996    False
# 11997    False
# 11998    False
# 11999    False
# Name: order_date, Length: 12000, dtype: bool

# %%
data['order_date'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **11.What percentage of orders are returned?**

# %%
data["is_returned"].mean()#*100
# Out:
# np.float64(0.10258333333333333)

# %% [markdown]
# **12.Which product categories have the highest return rate?**

# %%
data1 = data.groupby('product_category')['is_returned'].mean().sort_values(ascending=False)
data1
# Out:
# product_category
# Furniture      0.112173
# Electronics    0.107831
# Books          0.103964
# Food           0.096721
# Clothing       0.092211
# Name: is_returned, dtype: float64

# %%
data1 = data1*100
data1
# Out:
# product_category
# Furniture      11.217283
# Electronics    10.783055
# Books          10.396440
# Food            9.672063
# Clothing        9.221053
# Name: is_returned, dtype: float64

# %% [markdown]
# **13.Which countries contribute the most orders and revenue?**

# %%
data.groupby('country')['total_price'].sum().sort_values(ascending=False)
# Out:
# country
# Germany    2314896.10
# Canada     2312891.23
# UK         2285856.94
# India      2267182.87
# USA        2248307.23
# Name: total_price, dtype: float64

# %% [markdown]
# **14.Does quantity correlate with total_price?**

# %%
data[['quantity','total_price']].corr()
# Out:
#              quantity  total_price
# quantity     1.000000     0.600021
# total_price  0.600021     1.000000

# %% [markdown]
# **15 . FIND THE HIGHEST COUNTRY PURCHASED THE PRODUCT ?**

# %%
# countplot() counts categories by itself.
# You must pass only ONE axis (x or y), not both.

data["country"]
sns.countplot(x = "country" , data=data)
plt.show()

# %% [markdown]
# **16 . WHAT IS THE PROBABILITY OF RETURN PRODUCTS ?**

# %%
probability_of_return = data["customer_age"] == data["product_category"]
probability_of_return
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11995    False
# 11996    False
# 11997    False
# 11998    False
# 11999    False
# Length: 12000, dtype: bool

# %%
probability_of_return.groupby(probability_of_return).size()
# Out:
# False    12000
# dtype: int64

# %% [markdown]
# **17 . FIND THE TOTAL ORDER ID ?**

# %%
data["order_id"].count()
# Out:
# np.int64(12000)

# %% [markdown]
# **18 . FIND THE DUPLICATE ROW IN THE DATASET ?**

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **19 . FIND THE COUNTRY PRODUCT QUANTITY WITH PRODUCT ?**

# %%
sns.catplot(x='country', y='quantity', hue ='product_category', kind='bar', data=data) # hue=legend 
plt.title("Catplot Example")
plt.show();
